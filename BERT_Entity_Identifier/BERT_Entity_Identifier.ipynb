# %%
# !pip install simpletransformers
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 250.7/250.7 kB 6.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.2/7.2 MB 70.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 474.6/474.6 kB 36.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.6/43.6 kB 5.0 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 64.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 61.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.9/8.9 MB 97.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 56.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 236.8/236.8 kB 24.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 73.2 MB/s eta 0:00:00
# ...

# %% [markdown]
# # New section

# %%
import json
import logging
from simpletransformers.question_answering import QuestionAnsweringModel, QuestionAnsweringArgs

model_type="bert"
model_name= "bert-base-cased"

with open(r"/content/train.json", "r") as read_file:
    train = json.load(read_file)


with open(r"/content/test.json", "r") as read_file:
    test = json.load(read_file)

# %%
# Configure the model 
model_args = QuestionAnsweringArgs()
model_args.train_batch_size = 16
model_args.evaluate_during_training = True
model_args.n_best_size=3
model_args.num_train_epochs=5

# %%
### Advanced Methodology
train_args = {
    "reprocess_input_data": True,
    "overwrite_output_dir": True,
    "use_cached_eval_features": True,
    "output_dir": f"outputs/{model_type}",
    "best_model_dir": f"outputs/{model_type}/best_model",
    "evaluate_during_training": True,
    "max_seq_length": 128,
    "num_train_epochs": 20,
    "evaluate_during_training_steps": 1000,
    "wandb_project": "BERT Entity Identifier",
    "wandb_kwargs": {"name": model_name},
    "save_model_every_epoch": False,
    "save_eval_checkpoints": False,
    "n_best_size":3,
    # "use_early_stopping": True,
    # "early_stopping_metric": "mcc",
    # "n_gpu": 2,
    # "manual_seed": 4,
    # "use_multiprocessing": False,
    "train_batch_size": 128,
    "eval_batch_size": 64,
    # "config": {
    #     "output_hidden_states": True
    # }
}

# %% [markdown]
# # New section

# %%
model = QuestionAnsweringModel(
    model_type,model_name, args=train_args, use_cuda = False
)
# Out:
# Some weights of the model checkpoint at bert-base-cased were not used when initializing BertForQuestionAnswering: ['cls.seq_relationship.bias', 'cls.predictions.transform.LayerNorm.bias', 'cls.predictions.transform.LayerNorm.weight', 'cls.seq_relationship.weight', 'cls.predictions.transform.dense.bias', 'cls.predictions.bias', 'cls.predictions.transform.dense.weight']
# - This IS expected if you are initializing BertForQuestionAnswering from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertForQuestionAnswering from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# ...

# %%
# Train the model
model.train_model(train, eval_data=test)
# Out:
# convert squad examples to features:   0%|          | 0/37 [00:00<?, ?it/s]Could not find answer: 'black coffee with two sugar and two cream, please.' vs. 'small black coffee with two sugar and two cream'
# Could not find answer: 'tea triple triple.' vs. 'tea double double'
# ...
# Epoch:   0%|          | 0/20 [00:00<?, ?it/s]
# wandb: Logging into wandb.ai. (Learn how to deploy a W&B server locally: https://wandb.me/wandb-server)
# wandb: You can find your API key in your browser here: https://wandb.ai/authorize
# wandb: Paste an API key from your profile and hit enter, or press ctrl+c to quit:
#  ··········
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# Tracking run with wandb version 0.15.4
# Run data is saved locally in <code>/content/wandb/run-20230609_230523-a60a3em6</code>
# ...

# %%
# Evaluate the model
result, texts = model.eval_model(test)
print(result)
# Out:
# Running Evaluation:   0%|          | 0/1 [00:00<?, ?it/s]
# {'correct': 7, 'similar': 0, 'incorrect': 1, 'eval_loss': -4.471423149108887}

# %%
# Make predictions with the model
to_predict = [
{
      "context": "I will have a small black coffee with two sugar and two cream, please.",
      "qas": [
        { "id": "001001",
          "question": "What was the items ordered?"
        }
      ]
    }
]
answers, probabilities = model.predict(to_predict)

print(answers)
# Out:
# ...
# Running Prediction:   0%|          | 0/1 [00:00<?, ?it/s]
# [{'id': '001001', 'answer': ['small black coffee with two sugar and two cream', 'black coffee with two sugar and two cream', 'small black coffee']}]

# %%
texts
# Out:
# {'correct_text': {'00605': 'medium capuccino with two sugar and two cream',
#   '000607': 'small chai tea with no sugar and two cream',
#   '000611': 'triple shot espresso',
#   '000613': 'medium latte with almond milk',
#   '000615': 'rose tea triple triple',
#   '000617': 'large masala tea with three sugar and one cream',
#   '000619': 'large kashmiri tea double double'},
#  'similar_text': {},
#  'incorrect_text': {'000609': {'truth': 'small black pekoka tea with two sugar and two cream',
#    'predicted': 'small pekoka tea with two sugar and two cream',
#    'question': 'What was the items ordered?'}}}

# %%
### Remove output folder where training result is stored
# !rm -rf outputs
